# %%
import numpy as np
import pandas as pd

# %%
np.set_printoptions(suppress = True, linewidth = 100, precision = 2)

# %%
raw_data = pd.read_csv("/Users/User/Desktop/Data Analyst Course/S32 - The Absenteeism Exercise - Introduction/Files/Absenteeism-data.csv",)
raw_data
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
type(raw_data)
# Out:
# pandas.core.frame.DataFrame

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         700 non-null    int64
#  1   Reason for Absence         700 non-null    int64
#  2   Date                       700 non-null    object
#  3   Transportation Expense     700 non-null    int64
#  4   Distance to Work           700 non-null    int64
#  5   Age                        700 non-null    int64
#  6   Daily Work Load Average    700 non-null    float64
#  7   Body Mass Index            700 non-null    int64
#  8   Education                  700 non-null    int64
#  9   Children                   700 non-null    int64
#  10  Pets                       700 non-null    int64
#  11  Absenteeism Time in Hours  700 non-null    int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 65.8+ KB

# %%
def checkpoint(file_name, checkpoint_header, checkpoint_data):
    np.savez(file_name, header = checkpoint_header, data = checkpoint_data)
    checkpoint_variable = np.load(file_name + ".npz")
    return(checkpoint_variable)

# %%
df = raw_data.copy()

# %%
df = df.drop(['ID'], axis = 1)

# %%
# Define the bin edges for grouping
bins = [-1, 0, 14, 17, 21, 28]

# Define the labels for each group
labels = [0, 1, 2, 3, 4]

# Use the cut() function to assign groups based on the column values
df['Reason for Absence'] = pd.cut(df['Reason for Absence'], bins=bins, labels=labels, right = True)

# %%
df
# Out:
#     Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    4  07/07/2015                     289                36
# 1                    0  14/07/2015                     118                13
# 2                    4  15/07/2015                     179                51
# 3                    1  16/07/2015                     279                 5
# 4                    4  23/07/2015                     289                36
# ..                 ...         ...                     ...               ...
# 695                  1  23/05/2018                     179                22
# 696                  1  23/05/2018                     225                26
# 697                  1  24/05/2018                     330                16
# 698                  4  24/05/2018                     235                16
# 699                  4  31/05/2018                     291                31
#
# ...

# %%
df['Reason for Absence'].isnull().sum()
# Out:
# 0

# %%
date_split = df['Date'].str.split('/', n = 2, expand = True)
date_split
# Out:
#       0   1     2
# 0    07  07  2015
# 1    14  07  2015
# 2    15  07  2015
# 3    16  07  2015
# 4    23  07  2015
# ..   ..  ..   ...
# 695  23  05  2018
# 696  23  05  2018
# 697  24  05  2018
# 698  24  05  2018
# 699  31  05  2018
#
# [700 rows x 3 columns]

# %%
date_split = date_split.rename(columns = {0: 'Day', 1: 'Month', 2: 'Year'})
date_split
# Out:
#     Day Month  Year
# 0    07    07  2015
# 1    14    07  2015
# 2    15    07  2015
# 3    16    07  2015
# 4    23    07  2015
# ..   ..   ...   ...
# 695  23    05  2018
# 696  23    05  2018
# 697  24    05  2018
# 698  24    05  2018
# 699  31    05  2018
#
# [700 rows x 3 columns]

# %%
date_split = date_split.drop(['Day','Year'], axis = 1)

# %%
date_split
# Out:
#     Month
# 0      07
# 1      07
# 2      07
# 3      07
# 4      07
# ..    ...
# 695    05
# 696    05
# 697    05
# 698    05
# 699    05
#
# [700 rows x 1 columns]

# %%
type(df['Date'][0])
# Out:
# str

# %%
df['Date'] = pd.to_datetime(df['Date'], format = 'mixed')

# %%
df['Date']
# Out:
# 0     2015-07-07
# 1     2015-07-14
# 2     2015-07-15
# 3     2015-07-16
# 4     2015-07-23
#          ...
# 695   2018-05-23
# 696   2018-05-23
# 697   2018-05-24
# 698   2018-05-24
# 699   2018-05-31
# Name: Date, Length: 700, dtype: datetime64[ns]

# %%
def date_to_weekday(date_value):
    return date_value.weekday()

# %%
df['Day of the Week'] = df['Date'].apply(date_to_weekday)

# %%
df
# Out:
#     Reason for Absence       Date  Transportation Expense  Distance to Work  \
# 0                    4 2015-07-07                     289                36
# 1                    0 2015-07-14                     118                13
# 2                    4 2015-07-15                     179                51
# 3                    1 2015-07-16                     279                 5
# 4                    4 2015-07-23                     289                36
# ..                 ...        ...                     ...               ...
# 695                  1 2018-05-23                     179                22
# 696                  1 2018-05-23                     225                26
# 697                  1 2018-05-24                     330                16
# 698                  4 2018-05-24                     235                16
# 699                  4 2018-05-31                     291                31
#
# ...

# %%
df = pd.concat([df,date_split], axis = 1)

# %%
df = df.drop(['Date'], axis = 1)

# %%
df
# Out:
#     Reason for Absence  Transportation Expense  Distance to Work  Age  \
# 0                    4                     289                36   33
# 1                    0                     118                13   50
# 2                    4                     179                51   38
# 3                    1                     279                 5   39
# 4                    4                     289                36   33
# ..                 ...                     ...               ...  ...
# 695                  1                     179                22   40
# 696                  1                     225                26   28
# 697                  1                     330                16   28
# 698                  4                     235                16   32
# 699                  4                     291                31   40
#
#      Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# ...

# %%
df['Education'].unique()+
# Out:
# array([1, 3, 2, 4], dtype=int64)
